# %% [markdown]
# # SVM (Interview Level) — Student Lab
#
# We use sklearn here, but you still compute hinge loss and reason about margins.

# %%
import numpy as np
from sklearn.svm import LinearSVC, SVC
from sklearn.preprocessing import StandardScaler

def check(name: str, cond: bool):
    if not cond:
        raise AssertionError(f'Failed: {name}')
    print(f'OK: {name}')

rng = np.random.default_rng(0)

# %% [markdown]
# ## Section 0 — Synthetic datasets
# We create 2D datasets for intuition.

# %%
def make_linear(n=300, sep=2.0):
    X0 = rng.standard_normal((n//2, 2)) + np.array([0,0])
    X1 = rng.standard_normal((n-n//2, 2)) + np.array([sep,0])
    X = np.vstack([X0, X1])
    y = np.array([0]*len(X0) + [1]*len(X1))
    p = rng.permutation(n)
    return X[p], y[p]

def make_xor(n=400, noise=0.2):
    X = rng.uniform(-1, 1, size=(n,2)) 
    y = (X[:,0]*X[:,1] > 0).astype(int)
    # add noise
    flip = rng.random(n) < noise
    y[flip] = 1 - y[flip]
    return X, y

X_lin, y_lin = make_linear()
X_xor, y_xor = make_xor()
X_lin.shape, X_xor.shape
# Out:
# ((300, 2), (400, 2))

# %% [markdown]
# ## Section 1 — Hinge loss
#
# ### Task 1.1: Implement hinge loss for y in {-1,+1}
#
# L = mean(max(0, 1 - y*(Xw + b)))
#
# # HINT: convert y from {0,1} to {-1,+1} as y2 = 2y-1

# %%
# SVM : is a linear classifier that finds the hyperplane that maximizes the margin between classes. It can be extended to non-linear decision boundaries using kernels.
# Cons : 
# Kernel SVM is slow on large datasets.
# Hyperparameter matter a lot in SVM
# Hard to interpret the model, especially with non-linear kernels.
# sensitive to feature scaling, so it often requires careful preprocessing.

# Pros of SVM:
# - Effective in high-dimensional spaces.
# - Can model non-linear decision boundaries with kernels.
# - Robust to overfitting, especially in high-dimensional space.

# Hinge loss is a loss function used in SVMs to measure the error of predictions. It penalizes misclassifications and margin violations, encouraging the model to find a decision boundary that maximizes the margin between classes.

def hinge_loss(X, y_pm1, w, b):
    # TODO
    margins = y_pm1 * (X @ w + b) 
    np.maximum(0.0, 1.0 - margins) #Hinge loss formula
    return float(np.mean(np.maximum(0.0, 1.0 - margins)))

X = np.array([[1.0, 0.0], [0.0, 1.0]])
y = np.array([1, 0])
y_pm1 = 2*y - 1 # convert to +1/-1 , [1, -1]
w = np.array([1.0, -1.0])
b = 0.0 # bias term
L = hinge_loss(X, y_pm1, w, b)
print('hinge', L)
check('finite', np.isfinite(L))
# Out:
# hinge 0.0
# OK: finite

# %% [markdown]
# ## Section 2 — Linear SVM (LinearSVC)
#
# ### Task 2.1: Standardize + fit for different C
#
# **FAANG gotcha:** Without scaling, SVM behaves poorly.

# %%
def fit_linear_svm(X, y, C): # X : features matrix, y : labels(spam 1, ham 0), C : regularization parameter
    scaler = StandardScaler() # SVM is sensitive to feature scaling, so we standardize the features to have zero mean and unit variance.
    Xs = scaler.fit_transform(X) # fit: compute the mean and std of X, transform: apply the scaling to X
    clf = LinearSVC(C=C, max_iter=20000, random_state=0)
    clf.fit(Xs, y)
    return scaler, clf

Cs = [0.01, 0.1, 1.0, 10.0]
for C in Cs:
    scaler, clf = fit_linear_svm(X_lin, y_lin, C)
    acc = clf.score(scaler.transform(X_lin), y_lin)
    print('C', C, 'train_acc', acc)
# Out:
# C 0.01 train_acc 0.8633333333333333
# C 0.1 train_acc 0.8633333333333333
# C 1.0 train_acc 0.8633333333333333
# C 10.0 train_acc 0.8633333333333333
# /Users/pallavi/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /Users/pallavi/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /Users/pallavi/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /Users/pallavi/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %% [markdown]
# ## Section 3 — Kernel SVM (RBF)
#
# ### Task 3.1: XOR dataset
# Train:
# - linear kernel (should struggle)
# - RBF kernel (should improve)

# %%
# Kerner SVM is responseble for the non-linear decision boundary by intentinally mapping the input features into a higher-dimensional space.
# RBF is radial basis function kernel, which is a popular choice for non-linear SVMs. 

scaler = StandardScaler() # Standardize features for kernel SVM
Xx = scaler.fit_transform(X_xor) 

clf_lin = SVC(kernel='linear', C=1.0)
clf_rbf = SVC(kernel='rbf', C=1.0, gamma='scale')

clf_lin.fit(Xx, y_xor)
clf_rbf.fit(Xx, y_xor)

print('linear acc', clf_lin.score(Xx, y_xor))
print('rbf acc', clf_rbf.score(Xx, y_xor))
# Out:
# linear acc 0.52
# rbf acc 0.735

# %% [markdown]
# ## Section 4 — Failure modes
#
# ### Task 4.1: Show scaling sensitivity
# Multiply one feature by 1000 and compare performance with/without StandardScaler.

# %%
X_bad = X_lin.copy()
X_bad[:, 1] *= 1000

# without scaling
clf = LinearSVC(C=1.0, max_iter=20000, random_state=0)
clf.fit(X_bad, y_lin)
acc_noscale = clf.score(X_bad, y_lin)

# with scaling
scaler = StandardScaler()
Xs = scaler.fit_transform(X_bad)
clf2 = LinearSVC(C=1.0, max_iter=20000, random_state=0)
clf2.fit(Xs, y_lin)
acc_scale = clf2.score(Xs, y_lin)

print('acc_noscale', acc_noscale, 'acc_scale', acc_scale)
check('scaling_helpful', acc_scale >= acc_noscale - 1e-9)
# Out:
# acc_noscale 0.6633333333333333 acc_scale 0.8633333333333333
# OK: scaling_helpful
# /Users/pallavi/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /Users/pallavi/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/pallavi/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %% [markdown]
# ---
# ## Submission Checklist
# - Hinge loss implemented
# - C sweep shown
# - Linear vs RBF on XOR shown
# - Scaling failure demonstrated
